# %%
import matplotlib.pyplot as plt
import numpy as np
import csv
from scipy.optimize import curve_fit

# %%
#Функции аппроксимации
def func1(x, a):
    return a * x

def func2(x, a, b):
    return a * np.log2(b * x)

# %%
with open('Search_worst.csv', 'r') as file:
    reader = csv.reader(file)
    number=[]
    time1=[]
    time2=[]
    for row in reader:
        number.append(int(row[0]))
        time1.append(float(row[1]))
        time2.append(float(row[2]))

# %%
plt.plot(number,time1,marker='o',markersize=5,ls='', color='hotpink')
popt, pcov = curve_fit(func1, number, time1)
plt.plot(number, func1(np.array(number), *popt), label = f"Аппроксимация $t={popt[0]:.3f}n$")
plt.xlabel("Длина массива $n$")
plt.ylabel("Время $t$, мкс")
plt.title("Поиск перебором. Наихудший вариант")
plt.legend()
plt.show()

# %%
plt.plot(number,time2,marker='o',markersize=5,ls='', color='hotpink')
popt, pcov = curve_fit(func2, number, time2)
plt.plot(number,func2(np.array(number), *popt), label = f"Аппроксимация $t={popt[0]:.3f}\log({popt[1]:.3f}n)$")
plt.xlabel("Длина массива $n$")
plt.ylabel("Время $t$, мкс")
plt.title("Бинарный поиск. Наихудший вариант")
plt.legend()
plt.show()
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\l'
# <>:3: SyntaxWarning: invalid escape sequence '\l'
# /tmp/ipykernel_5364/1924573370.py:3: SyntaxWarning: invalid escape sequence '\l'
#   plt.plot(number,func2(np.array(number), *popt), label = f"Аппроксимация $t={popt[0]:.3f}\log({popt[1]:.3f}n)$")
