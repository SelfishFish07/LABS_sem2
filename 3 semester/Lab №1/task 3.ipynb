# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dd = np.loadtxt('data_3.txt')
x=np.arange(1,101)

# %%
plt.bar(x,dd)
plt.xlabel("Value")
plt.ylabel("Probability")
plt.title("Histogram for DoubleDice(100)")
# Out:
# Text(0.5, 1.0, 'Histogram for DoubleDice(100)')
